# %% [markdown]
# When I scraped i did it by day, this is my script to re combine all of my data back into one csv

# %%
import os
import glob
import pandas as pd
from google.colab import drive # this will be our driver 
drive.mount('/content/gdrive')
owd = os.getcwd()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# takes each year and combines them

# %%
gen_path = '/content/gdrive/MyDrive/OpenInsider/Saved_data'
years = ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
for year in years:
  os.chdir(gen_path + '/' + year)
  extension = 'csv'
  all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
  combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
  combined_csv.to_csv( "OpenInsider_" + year + ".csv", index=False, encoding='utf-8-sig')

os.chdir(owd)

# %% [markdown]
# takes each year's combined file and combines them

# %%
year_path = '/content/gdrive/MyDrive/OpenInsider/Saved_data/Years'
os.chdir(year_path)
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv.to_csv( "OpenInsider_all.csv", index=False, encoding='utf-8-sig')

os.chdir(owd)

# %%
# %load_ext google.colab.data_table
len(combined_csv) * 12
combined_csv
# Out:
# 14373480
